# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
input_file = "dataset_Facebook_formated.csv"

# %%
data_frame = pd.read_csv(input_file)

# %%
df2 = data_frame.dropna()

# %%
df_mask=df2['Paid']==1

# %%
df_mask2=df2['Paid']==0

# %%
df_only_paid= df2[df_mask]

# %%
df_only_non_paid = df2[df_mask2]

# %%
df_only_paid
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441     1         2          12             2         10
# 6              139441     1         3          12             1          3
# 7              139441     1         3          12             7          9
# 14             138414     1         2          12             4          5
# 17             138414     1         1          12             2         12
# ..                ...   ...       ...         ...           ...        ...
# 475             86909     1         3           1             6         16
# 476             86909     1         1           1             6         10
# 481             86491     2         1           1             4          4
# 491             85979     1         3           1             6          3
# 499             81370     1         2           1             4          4
#
# ...

# %%
df_only_non_paid
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441     1         2          12             4          3
# 1              139441     3         2          12             3         10
# 2              139441     1         3          12             3          3
# 4              139441     1         2          12             2          3
# 5              139441     3         2          12             1          9
# ..                ...   ...       ...         ...           ...        ...
# 494             85093     1         3           1             7         10
# 495             85093     1         3           1             7          2
# 496             81370     1         2           1             5          8
# 497             81370     1         1           1             5          2
# 498             81370     1         3           1             4         11
#
# ...

# %%
df_only_non_paid.mean()
# Out:
# Page total likes                                                       123078.129213
# Type                                                                        1.266854
# Category                                                                    1.901685
# Post Month                                                                  7.058989
# Post Weekday                                                                4.129213
# Post Hour                                                                   8.033708
# Paid                                                                        0.000000
# Lifetime Post Total Reach                                               11974.314607
# Lifetime Post Total Impressions                                         26926.283708
# Lifetime Engaged Users                                                    856.668539
# Lifetime Post Consumers                                                   751.882022
# ...

# %%
df_only_paid.mean()
# Out:
# Page total likes                                                       123116.600000
# Type                                                                        1.271429
# Category                                                                    1.850000
# Post Month                                                                  6.907143
# Post Weekday                                                                4.142857
# Post Hour                                                                   7.335714
# Paid                                                                        1.000000
# Lifetime Post Total Reach                                               19180.300000
# Lifetime Post Total Impressions                                         37148.150000
# Lifetime Engaged Users                                                   1102.650000
# Lifetime Post Consumers                                                   935.078571
# ...
